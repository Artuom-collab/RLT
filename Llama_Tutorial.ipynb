# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtuomMerkulov/RLT.HAck/blob/main/Llama_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Загрзка

# %%
# !pip install llama-index
# !pip install llama-index-core
# !pip install llama-index-embeddings-openai
# !pip install llama-index-postprocessor-flag-embedding-reranker
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# !pip install llama-parse
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

import os
# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = "llx-dANieXc3oHcdK7WvRNBXM58SYvlXRVL6aQxmJQbZZpoeI89v"
# Using OpenAI API for embeddings/llms
os.environ["OPENAI_API_KEY"] = "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"

from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader
from llama_index.core import Settings

embed_model=OpenAIEmbedding(model="text-embedding-3-small")
llm = OpenAI(model="gpt-3.5-turbo-0125")

Settings.llm = llm
Settings.embed_model = embed_model
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader
documents = SimpleDirectoryReader("data").load_data()

# %%
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader
index=VectorStoreIndex.from_documents(documents)
query_engine= index.as_query_engine()
response= query_engine.query("Зачем нужна лицензия на торговлю?")
from IPython.display import Markdown, display
display(Markdown(f"<b>{response}</b>"))
index.storage_context.persist()
# Out:
# <b>Для осуществления торговли требуется лицензия, чтобы обеспечить недискриминационный доступ к определенным товарам и инфраструктуре, а также для обеспечения прозрачности условий обращения товаров на рынке и доступа на рынок. Лицензия также необходима для определения условий договоров о доступе на рынок, возмещения расходов на производство и реализацию товаров, проведения конкурсных процедур доступа на рынок, и других аспектов, связанных с регулированием торговли.</b>

# %%
response= query_engine.query("В чем польза цифровой подписи?")
from IPython.display import Markdown, display
display(Markdown(f"<b>{response}</b>"))
index.storage_context.persist()
# Out:
# <b>The benefit of a digital signature is that it provides authenticity, integrity, and non-repudiation to electronic documents and transactions.</b>

# %%
response= query_engine.query("Какие продавец должен иметь документы")
from IPython.display import Markdown, display
display(Markdown(f"<b>{response}</b>"))
index.storage_context.persist()
# Out:
# <b>Продавец должен иметь документы, подтверждающие его реквизиты, срок действия документов, а также документы, подтверждающие его статус выгодоприобретателя, бенефициарного владельца или контролирующего лица заявителя.</b>

# %%
from llama_index.core import StorageContext,load_index_from_storage
storage_context=StorageContext.from_defaults(persist_dir="./storage")
index= load_index_from_storage(storage_context=storage_context)
